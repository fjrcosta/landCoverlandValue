# %% [markdown]
# # Inferência do bestAG do TabPFN sobre os grids urbanos
#
# Estima o valor unitário do terreno em cada ponto das grades de estimação das 12
# cidades, com intervalo dado pelos quantis 0,10 e 0,90 da distribuição preditiva.
#
# **O que muda em relação ao `tabular_FullPr_BestAG_inferencia.ipynb`**
#
# | | notebook antigo | este |
# |---|---|---|
# | `tps` | `Rbf(..., smooth=0.05)`, sem bloco polinomial, coordenadas padronizadas eixo a eixo | `spatial_features.fit_surface`, λ=1,0, transformação isotrópica, clip ao intervalo da resposta de ajuste |
# | configuração | `mod54 + feat1..feat512`, que não é nenhuma das 64 | o **bestAG do TabPFN lido dos CSVs da etapa 2**, automaticamente |
# | limpeza e partição | reimplementadas na célula 1 | lidas do dataset canônico, via `benchmark_data.load_splits` |
# | dtype | `float32` | float64, como os nove estimadores desde 01/08 |
# | saída | predição pontual | quantis 0,10 / 0,50 / 0,90 e amplitude |
#
# **Regra do `tps` que este notebook respeita.** A superfície é ajustada **na amostra
# de treino** e lida nos pontos do grid — exatamente o regime de validação e teste da
# etapa 2, cujas respostas nunca entram em ajuste nenhum. As linhas de treino que
# alimentam o TabPFN mantêm os valores **out-of-fold** já materializados no canônico:
# são esses que o modelo do artigo viu, e trocá-los aqui produziria outro modelo.

# %%
# Ambiente: tabular-env (tabpfn 6.0.4)
import json
import os
import random
import sys
from datetime import datetime
from pathlib import Path

import geopandas as gpd
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from pyproj import Transformer
from shapely.geometry import Polygon
from sklearn.preprocessing import StandardScaler
from tabpfn import TabPFNRegressor

PROJETO = Path("/Volumes/ssd_externo/projects_full/Tabular/modelos_newTPS")
sys.path.insert(0, str(PROJETO))
sys.path.insert(0, str(PROJETO / "etapa2" / "benchmark"))

from benchmark_config import BY_MODEL_NUMBER          # noqa: E402
from benchmark_data import load_splits                # noqa: E402
from benchmark_results import best_by_class, load_metrics  # noqa: E402
from spatial_features import fit_surface, isotropic_transform  # noqa: E402

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["PYTHONHASHSEED"] = str(SEED)

# --------------------------------------------------------------------------
# CONSTANTES DA INFERÊNCIA
# --------------------------------------------------------------------------
# QUAL CONDIÇÃO DE SELEÇÃO. É o único interruptor do notebook: tudo a jusante
# passa por CONFIGURACAO, COLUNAS e sufixo, então rodar com um valor e depois
# com o outro produz as duas rodadas sem sobrescrever nada.
#
#   False   o bestAG irrestrito, que contém SS
#   True    o bestAG entre as configurações que EXCLUEM SS
#
# O suavizador é construído a partir dos log-preços observados, e a alegação de
# substituição do artigo repousa apenas em configurações sem ele; a rodada com
# True é a que corresponde a essa condição. A configuração NÃO é transcrita em
# nenhum dos dois casos: sai de best_by_class, na célula 3.
EXCLUIR_SS = True

# Terreno paradigma: a coluna `area` do grid é SOBRESCRITA por este valor, de
# modo que o mapa mostre a variação espacial do preço para um terreno padrão.
# 450 m2 é a mediana do BRPR12K (p25 = 302, p75 = 734). Os arquivos de grid
# vinham com 363 m2, que é o percentil 36.
AREA_PARADIGMA_M2 = 450.0

# Data de referência da avaliação. NENHUMA feature do modelo codifica tempo:
# este valor é metadado, entra nos títulos e nos arquivos de saída, e não altera
# a predição.
DATA_REFERENCIA = "2026-08-01"

# Penalidade de energia de flexão da superfície, fixada na etapa 1.
#
# A etapa 1 fixou DOIS parâmetros, lambda = 1,0 e bloco de 1 km, mas aqui só o
# lambda se aplica. O bloco é salvaguarda do regime OUT-OF-FOLD, que existe
# apenas para as linhas de AJUSTE: impede que um terreno entre na superfície que o
# prediz. Ponto de grade não tem resposta e não pode vazar nada, então recebe a
# superfície ajustada no treino completo -- a mesma regra que a etapa 2 aplica a
# validação e teste, e por isso sem blocos.
SMOOTHING = 1.0

# Quantis da distribuição preditiva do TabPFN.
QUANTIS = [0.10, 0.50, 0.90]

# Predição em BLOCOS, para não estourar memória com ~73 mil pontos. Nada a ver
# com a área do terreno: é só quantos pontos vão de uma vez ao estimador.
TAMANHO_BLOCO = 2000

# CRS das coordenadas UTM. O dataset traz lat/long ORIGINAIS e o UTM derivado
# delas, o que permite descobrir o CRS em vez de escolhê-lo: reconstruindo o
# lat/long a partir do utm_x/utm_y das 12.196 observações do canônico,
#
#     EPSG:29192  (SAD69/UTM 22S)     erro mediano  0,0 m   máximo  0,1 m
#     EPSG:32722  (WGS84/UTM 22S)     erro mediano 66,5 m   máximo 66,6 m
#     EPSG:31982  (SIRGAS2000/22S)    erro mediano 66,5 m   máximo 66,6 m
#
# O notebook antigo usava 32722 e deslocava a grade inteira em 66,5 m — mais de
# meia célula de 109,45 m — contra perímetros que já vêm em coordenadas
# geográficas. Os grids só trazem UTM, então esta volta é inevitável.
CRS_GRID = "EPSG:29192"
ESPACAMENTO_GRID_M = 109.45

DIR_GRIDS = Path("/Volumes/ssd_externo/projects_full/Tabular/dados_inferencia")
DIR_PERIMETROS = Path(
    "/Volumes/ssd_externo/UEL DOUTORADO 2022/Artigo GEO/json dados/shapeFiles"
)
DIR_MAPAS = PROJETO / "etapa4" / "mapas"            # HTML e PDF
DIR_RESULTADOS = PROJETO / "etapa4" / "resultados"  # CSV por cidade e registro
for _pasta in (DIR_MAPAS, DIR_RESULTADOS):
    _pasta.mkdir(parents=True, exist_ok=True)

# Código estável por cidade, para compor o identificador de ponto. É uma lista
# CONGELADA: acrescentar cidade no fim preserva os identificadores já emitidos.
CIDADE_ID = {
    "Apucarana": 1, "Arapongas": 2, "Cambe": 3, "Cambira": 4,
    "Ibipora": 5, "Jandaia": 6, "Londrina": 7, "Mandaguari": 8,
    "Marialva": 9, "Maringa": 10, "Rolandia": 11, "Sarandi": 12,
}

print(f"resultados: {DIR_RESULTADOS}")
print(f"mapas:      {DIR_MAPAS}")
print(f"terreno paradigma: {AREA_PARADIGMA_M2:.0f} m2 | data de referência: {DATA_REFERENCIA}")
# Out:
# resultados: /Volumes/ssd_externo/projects_full/Tabular/modelos_newTPS/etapa4/resultados
# mapas:      /Volumes/ssd_externo/projects_full/Tabular/modelos_newTPS/etapa4/mapas
# terreno paradigma: 450 m2 | data de referência: 2026-08-01

# %% [markdown]
# ## 1. Qual é o bestAG
#
# Lido dos CSVs da etapa 2, nunca transcrito. `load_metrics` seleciona o arquivo de
# métricas mais recente de cada estimador, então basta rerodar o benchmark para que
# esta célula acompanhe.

# %%
metricas = load_metrics(["TabPFN"])
melhores = best_by_class(metricas, exclude_smoother=EXCLUIR_SS)

linha = melhores[(melhores.estimator == "TabPFN") & (melhores.category == "AG")]
if linha.empty:
    raise RuntimeError("nenhuma configuração AG do TabPFN nos resultados")
linha = linha.iloc[0]

CONFIGURACAO = int(linha.model_number)
COLUNAS = BY_MODEL_NUMBER[CONFIGURACAO]["columns"]
GRUPOS = BY_MODEL_NUMBER[CONFIGURACAO]["name"]
USA_SS = BY_MODEL_NUMBER[CONFIGURACAO]["includes_tps"]

condicao = "smoother-free" if EXCLUIR_SS else "irrestrita (SS permitido)"
print(f"condição         : {condicao}")
print(f"bestAG do TabPFN : configuração {CONFIGURACAO}")
print(f"grupos           : {GRUPOS}")
print(f"colunas          : {len(COLUNAS)}")
print(f"inclui SS (tps)  : {USA_SS}")
print(f"R2 de teste      : {linha.r2:.4f}")

if EXCLUIR_SS and USA_SS:
    raise RuntimeError(f"configuração {CONFIGURACAO} contém SS; "
                       "best_by_class não filtrou como esperado")
# Out:
# [ok] TabPFN: TabPFN_FULLDATA_metrics_20260801_173155.csv
# condição         : smoother-free
# bestAG do TabPFN : configuração 60
# grupos           : BASE + CENSUS + RS + COORDS + EMBED
# colunas          : 80
# inclui SS (tps)  : False
# R2 de teste      : 0.7073

# %% [markdown]
# ## 2. Amostra de ajuste e a superfície espacial
#
# O TabPFN é reajustado aqui **exatamente como no benchmark**: nas 8.532 observações
# de treino, com as mesmas colunas e a mesma padronização. As linhas de treino
# carregam o `tps` out-of-fold do dataset canônico — é o que o modelo do artigo viu.
#
# A superfície que servirá aos pontos do grid é ajustada no treino completo, e o
# `fit_surface` já aplica o clip ao intervalo empírico da resposta de ajuste.

# %%
X_train, X_test, X_val, y_train, y_test, y_val = load_splits()  # ordem: train, TEST, validation

coords_train = X_train[["utm_x", "utm_y"]].to_numpy(dtype=float)
resposta_train = y_train.to_numpy(dtype=float)

para_km = isotropic_transform(coords_train)
superficie = fit_surface(para_km(coords_train), resposta_train, SMOOTHING)

print(f"treino: {len(X_train)} observações")
print(f"resposta ln(unit): [{resposta_train.min():.4f}; {resposta_train.max():.4f}]")
print(f"superfície ajustada com lambda = {SMOOTHING}")
if USA_SS:
    print(f"tps do treino (out-of-fold, do canônico): "
          f"[{X_train['tps'].min():.4f}; {X_train['tps'].max():.4f}]  "
          f"Pearson com a resposta = {np.corrcoef(X_train['tps'], resposta_train)[0, 1]:.4f}")
# Out:
# treino: 8532 observações
# resposta ln(unit): [4.8233; 8.6036]
# superfície ajustada com lambda = 1.0

# %%
# Padronizador ajustado no treino, como em benchmarkTabPFN.py.
escalador = StandardScaler()
x_train = escalador.fit_transform(X_train[COLUNAS])

modelo = TabPFNRegressor(device="cpu", ignore_pretraining_limits=True)
modelo.fit(x_train, resposta_train)

# Conferência: o R2 de teste tem de bater com o do CSV da etapa 2.
x_test = escalador.transform(X_test[COLUNAS])
predito_teste = np.asarray(modelo.predict(x_test), dtype=float).reshape(-1)
observado = y_test.to_numpy(dtype=float)
r2_conferido = 1 - np.sum((observado - predito_teste) ** 2) / np.sum(
    (observado - observado.mean()) ** 2
)
print(f"R2 de teste reproduzido: {r2_conferido:.4f}  (CSV da etapa 2: {linha.r2:.4f})")
if abs(r2_conferido - linha.r2) > 1e-6:
    print("ATENÇÃO: divergência — o modelo aqui não é o do benchmark.")
# Out:
# R2 de teste reproduzido: 0.7073  (CSV da etapa 2: 0.7073)

# %% [markdown]
# ## 3. Perímetros urbanos e grades de estimação

# %%
PERIMETROS = {
    "Apucarana": "shpApucarana", "Arapongas": "shpArapongas", "Cambe": "shpCambe",
    "Cambira": "shpCambira", "Ibipora": "shpIbipora", "Jandaia": "shpjSul",
    "Londrina": "shpLondrina", "Mandaguari": "shpMandaguari",
    "Marialva": "shpMarialva", "Maringa": "shpMaringa",
    "Rolandia": "shpRolandia", "Sarandi": "shpSarandi",
}

perimetros = {}
for cidade, pasta in PERIMETROS.items():
    caminho = DIR_PERIMETROS / pasta / "perimetro.GeoJSON"
    if caminho.exists():
        perimetros[cidade] = gpd.read_file(caminho).to_crs("EPSG:4326")
    else:
        print(f"[ausente] {cidade}: {caminho}")
print(f"{len(perimetros)} perímetros carregados")
# Out:
# 12 perímetros carregados

# %%
grids = {}
for cidade in PERIMETROS:
    caminho = DIR_GRIDS / f"novos_dados{cidade}_com_renda.csv"
    if not caminho.exists():
        print(f"[ausente] {cidade}: {caminho.name}")
        continue
    grids[cidade] = pd.read_csv(caminho)

total = sum(len(g) for g in grids.values())
print(f"{len(grids)} grades, {total:,} pontos")

faltando = set(COLUNAS) - set(next(iter(grids.values())).columns) - {"tps"}
if faltando:
    raise RuntimeError(f"o grid não traz colunas exigidas pela configuração: {sorted(faltando)}")
print("as grades trazem todas as colunas da configuração, exceto tps — que é gerado a seguir")
# Out:
# 12 grades, 73,399 pontos
# as grades trazem todas as colunas da configuração, exceto tps — que é gerado a seguir

# %% [markdown]
# ## 4. O `tps` das grades
#
# Ponto do grid é ponto novo: sua resposta não existe e nunca entrou em ajuste
# nenhum. Recebe portanto o valor da superfície ajustada no treino completo, que é a
# mesma regra da validação e do teste na etapa 2.
#
# Aqui também se fixa o terreno paradigma, sobrescrevendo a coluna `area`.

# %%
for cidade, grid in grids.items():
    coords = grid[["utm_x", "utm_y"]].to_numpy(dtype=float)
    grid["tps"] = superficie(para_km(coords))
    grid["area"] = AREA_PARADIGMA_M2

resumo = pd.DataFrame([
    {"cidade": c, "pontos": len(g),
     "tps_min": g.tps.min(), "tps_mediana": g.tps.median(), "tps_max": g.tps.max()}
    for c, g in grids.items()
])
print(f"tps do treino, para referência: "
      f"[{resposta_train.min():.4f}; {resposta_train.max():.4f}] é o intervalo do clip")
print(resumo.round(4).to_string(index=False))
# Out:
# tps do treino, para referência: [4.8233; 8.6036] é o intervalo do clip
#     cidade  pontos  tps_min  tps_mediana  tps_max
#  Apucarana    9062   5.2930       5.6770   6.7565
#  Arapongas   10696   5.1135       6.2147   7.3548
#      Cambe    5922   4.8233       6.1699   6.9134
#    Cambira     238   5.2697       5.3522   5.5205
#    Ibipora    3916   5.4326       6.0550   7.1527
#    Jandaia    1696   5.2654       5.8068   6.1433
#   Londrina   18384   4.8233       6.5636   8.1841
# Mandaguari    3528   4.8823       5.6775   6.9462
#   Marialva    2304   5.3008       6.1743   6.6902
#    Maringa   11525   5.7322       6.7937   8.0185
#   Rolandia    3780   5.6278       5.9946   7.1589
#    Sarandi    2348   5.8602       6.3427   7.3232

# %% [markdown]
# ## 5. Predição por quantis
#
# `output_type="quantiles"` devolve os quantis da distribuição preditiva. A resposta
# está em ln(unit), então a volta à escala original é `exp`, e o valor total do
# terreno paradigma é o unitário vezes a área.
#
# Como `exp` é monótona, os quantis se transformam diretamente — não há correção de
# smearing a fazer, que só seria necessária para a média.

# %%
def predizer_quantis(modelo, x, quantis, tamanho_bloco):
    """Prediz em blocos, devolvendo um array (n, len(quantis))."""
    saida = np.empty((len(x), len(quantis)), dtype=float)
    for inicio in range(0, len(x), tamanho_bloco):
        fim = min(inicio + tamanho_bloco, len(x))
        bloco = modelo.predict(
            x[inicio:fim], output_type="quantiles", quantiles=quantis
        )
        saida[inicio:fim, :] = np.column_stack([np.asarray(q).reshape(-1) for q in bloco])
    return saida


# Fator de normalização do PINAW: amplitude da resposta OBSERVADA no conjunto
# de teste retido, em escala log — a mesma em que o modelo foi treinado.
# Khosravi et al. (2011). Normaliza-se pela amplitude do OBSERVADO, não pela do
# predito: é o que torna o PINAW comparável entre modelos e entre estudos.
R_TESTE = float(observado.max() - observado.min())
print(f"R (y_test, log) = {R_TESTE:.4f}   "
      f"[{observado.min():.4f}; {observado.max():.4f}]\n")

rotulos = [f"q{int(q * 100):02d}" for q in QUANTIS]
resultados = {}

for i, (cidade, grid) in enumerate(grids.items(), 1):
    x = escalador.transform(grid[COLUNAS])
    print(f"[{i}/{len(grids)}] {cidade}: {len(grid):,} pontos", flush=True)
    quantis = predizer_quantis(modelo, x, QUANTIS, TAMANHO_BLOCO)

    # Identificador EXATO. O ponto_id que vem no arquivo de origem não serve
    # como chave: em onze das doze cidades ele repete (Apucarana tem 9.062
    # linhas e id máximo 9.043). Constrói-se então um inteiro determinístico a
    # partir do código congelado da cidade e da POSIÇÃO da linha no arquivo,
    #
    #     id_ponto = CIDADE_ID * 10^7 + posição
    #
    # que é único, reconstruível e cabe em int64. O valor de origem é preservado
    # em ponto_id_origem, para rastrear até o arquivo, sem servir de chave.
    saida = grid[["utm_x", "utm_y"]].copy().reset_index(drop=True)
    saida.insert(0, "id_ponto",
                 CIDADE_ID[cidade] * 10_000_000 + np.arange(len(grid), dtype=np.int64))
    saida["ponto_id_origem"] = grid["ponto_id"].to_numpy(dtype=np.int64)
    saida["cidade"] = cidade
    saida["cidade_id"] = CIDADE_ID[cidade]
    saida["area_m2"] = AREA_PARADIGMA_M2
    saida["data_referencia"] = DATA_REFERENCIA
    saida["configuracao"] = CONFIGURACAO
    saida["tps"] = grid["tps"].to_numpy()
    for j, rotulo in enumerate(rotulos):
        saida[f"ln_unit_{rotulo}"] = quantis[:, j]
        saida[f"unit_{rotulo}"] = np.exp(quantis[:, j])
        saida[f"valor_{rotulo}"] = np.exp(quantis[:, j]) * AREA_PARADIGMA_M2
    saida["amplitude_unit"] = saida[f"unit_{rotulos[-1]}"] - saida[f"unit_{rotulos[0]}"]
    saida["amplitude_valor"] = saida["amplitude_unit"] * AREA_PARADIGMA_M2
    # PINAW, em escala LOG — largura do intervalo de 80% e sua versão
    # normalizada, w_i* = w_i / R, que é o campo mapeado adiante.
    saida["largura_log"] = quantis[:, -1] - quantis[:, 0]
    saida["pinaw_pontual"] = saida["largura_log"] / R_TESTE
    resultados[cidade] = saida

consolidado = pd.concat(resultados.values(), ignore_index=True)
if consolidado.id_ponto.nunique() != len(consolidado):
    raise RuntimeError("id_ponto não ficou único — a chave está quebrada")

# Um arquivo por cidade, mais o consolidado, que é o que os mapas consomem:
# a escala de cor é comum às doze, então eles precisam de todas juntas.
sufixo = f"cfg{CONFIGURACAO}_{AREA_PARADIGMA_M2:.0f}m2"
for cidade, saida in resultados.items():
    saida.to_csv(DIR_RESULTADOS / f"inferencia_{cidade}_{sufixo}.csv", index=False)
arquivo = DIR_RESULTADOS / f"inferencia_consolidado_{sufixo}.csv"
consolidado.to_csv(arquivo, index=False)
print(f"\n{len(resultados)} arquivos por cidade + {arquivo.name}")
print(f"{len(consolidado):,} pontos, id_ponto único de "
      f"{consolidado.id_ponto.min()} a {consolidado.id_ponto.max()}")
print(consolidado[["unit_q10", "unit_q50", "unit_q90", "amplitude_unit"]].describe().round(2).to_string())

# PINAW = (1 / (n * R)) * soma das larguras = média do w_i*
PINAW = float(consolidado["pinaw_pontual"].mean())
print(f"\nPINAW global (PINC 80%): {PINAW:.4f}   "
      f"w_i* de {consolidado.pinaw_pontual.min():.4f} a {consolidado.pinaw_pontual.max():.4f}")
print("\nPINAW por cidade — quanto MAIOR, mais larga a incerteza local:")
print(consolidado.groupby("cidade")
      .agg(pontos=("pinaw_pontual", "size"), pinaw=("pinaw_pontual", "mean"),
           w_min=("pinaw_pontual", "min"), w_max=("pinaw_pontual", "max"))
      .sort_values("pinaw", ascending=False).round(4).to_string())
# Out:
# R (y_test, log) = 3.7774   [4.8201; 8.5975]
#
# [1/12] Apucarana: 9,062 pontos
# [2/12] Arapongas: 10,696 pontos
# [3/12] Cambe: 5,922 pontos
# [4/12] Cambira: 238 pontos
# [5/12] Ibipora: 3,916 pontos
# [6/12] Jandaia: 1,696 pontos
# [7/12] Londrina: 18,384 pontos
# [8/12] Mandaguari: 3,528 pontos
# [9/12] Marialva: 2,304 pontos
# [10/12] Maringa: 11,525 pontos
# [11/12] Rolandia: 3,780 pontos
# [12/12] Sarandi: 2,348 pontos
#
# 12 arquivos por cidade + inferencia_consolidado_cfg60_450m2.csv
# 73,399 pontos, id_ponto único de 10000000 a 120002347
#        unit_q10  unit_q50  unit_q90  amplitude_unit
# count  73399.00  73399.00  73399.00        73399.00
# mean     413.54    669.41   1208.86          795.31
# std      239.09    395.36    725.52          581.84
# min      175.40    232.75    321.82           57.39
# 25%      270.04    411.04    736.75          429.43
# 50%      327.48    555.40    990.12          577.34
# 75%      459.55    797.51   1381.72          923.64
# ...

# %% [markdown]
# ## 6. Mapas
#
# Um mapa por camada: o piso do intervalo (quantil 0,10), a estimativa central
# (quantil 0,50), o teto (quantil 0,90) e a amplitude entre piso e teto. Cada ponto
# vira um quadrado do tamanho do espaçamento da grade. A paleta é a `tim.colors()`
# do R, e a escala de cor é **comum aos três mapas de valor** — piso, central e teto
# —, para que sejam comparáveis a olho. A amplitude tem escala própria, porque é
# uma diferença e não um nível.

# %% [markdown]
# ### PINAW
#
# Além dos três mapas de valor, gera-se o campo da **largura normalizada do
# intervalo preditivo**, na definição de Khosravi et al. (2011). Com cobertura
# nominal (PINC) de 80%, dada pelos quantis 0,10 e 0,90, a largura no ponto $i$ é
# $w_i = \hat{Q}_{0.90}^{(i)} - \hat{Q}_{0.10}^{(i)}$, e
#
# $$\mathrm{PINAW} = \frac{1}{n\,R}\sum_{i=1}^{n} w_i ,
# \qquad R = \max(y_{\text{teste}}) - \min(y_{\text{teste}}).$$
#
# Tudo em **escala log**, a mesma em que o modelo foi treinado. A normalização usa
# a amplitude da resposta OBSERVADA no conjunto de teste retido, não a do predito
# — é o que torna o valor comparável entre modelos e entre estudos. O escalar fica
# em $[0,1]$, e mais perto de zero significa intervalo mais estreito em relação à
# amplitude dos valores observados, isto é, maior nitidez.
#
# O mapa é do campo pontual $w_i^* = w_i / R$. Regiões de $w_i^*$ alto são onde o
# modelo devolve intervalo mais largo — o que se espera onde a densidade amostral
# de treino é baixa, nas zonas de transição entre municípios e na periferia do
# domínio espacial.

# %%
def tim_colors(n=1000):
    """Paleta tim.colors() do R."""
    cores = [
        "#000080", "#0000CC", "#0040FF", "#0080FF", "#00BFFF", "#00FFFF",
        "#00FFBF", "#00FF80", "#00FF40", "#00FF00", "#40FF00", "#80FF00",
        "#BFFF00", "#FFFF00", "#FFBF00", "#FF8000", "#FF4000", "#FF0000",
    ]
    mapa = mcolors.LinearSegmentedColormap.from_list("tim", cores, N=n)
    return mapa


CMAP = tim_colors()
_para_wgs = Transformer.from_crs(CRS_GRID, "EPSG:4326", always_xy=True)


def quadrado_wgs(utm_x, utm_y, meio):
    """Quadrado centrado no ponto, em [lat, lon] para o folium."""
    cantos = [
        (utm_x - meio, utm_y - meio), (utm_x + meio, utm_y - meio),
        (utm_x + meio, utm_y + meio), (utm_x - meio, utm_y + meio),
    ]
    return [[lat, lon] for lon, lat in (_para_wgs.transform(x, y) for x, y in cantos)]


def cor(valor, minimo, maximo):
    if maximo <= minimo:
        return mcolors.rgb2hex(CMAP(0.5))
    return mcolors.rgb2hex(CMAP(float(np.clip((valor - minimo) / (maximo - minimo), 0, 1))))

# %%
import folium
from branca.element import Template, MacroElement


def mapa_folium(dados, coluna, titulo, arquivo, minimo=None, maximo=None, unidade="R$/m2"):
    """Um mapa por camada, quadrados coloridos pela coluna pedida."""
    minimo = dados[coluna].min() if minimo is None else minimo
    maximo = dados[coluna].max() if maximo is None else maximo
    meio = ESPACAMENTO_GRID_M / 2

    centro_lon, centro_lat = _para_wgs.transform(dados.utm_x.mean(), dados.utm_y.mean())
    mapa = folium.Map(location=[centro_lat, centro_lon], zoom_start=10,
                      tiles="CartoDB positron")

    for perimetro in perimetros.values():
        folium.GeoJson(
            perimetro,
            style_function=lambda _: {"fillOpacity": 0, "color": "#444444", "weight": 1},
        ).add_to(mapa)

    camada = folium.FeatureGroup(name=titulo)
    for linha in dados.itertuples(index=False):
        valor = getattr(linha, coluna)
        folium.Polygon(
            locations=quadrado_wgs(linha.utm_x, linha.utm_y, meio),
            color=None, weight=0, fill=True,
            fill_color=cor(valor, minimo, maximo), fill_opacity=0.75,
            tooltip=f"{linha.cidade}<br>{coluna}: {valor:,.0f} {unidade}",
        ).add_to(camada)
    camada.add_to(mapa)

    escala = "".join(
        f'<span style="background:{mcolors.rgb2hex(CMAP(t))};width:14px;height:12px;'
        f'display:inline-block"></span>' for t in np.linspace(0, 1, 40)
    )
    legenda = MacroElement()
    legenda._template = Template(f"""
    {{% macro html(this, kwargs) %}}
    <div style="position:fixed;bottom:24px;left:24px;z-index:9999;background:white;
                padding:10px 14px;border:1px solid #999;font:12px sans-serif">
      <b>{titulo}</b><br>
      <span style="font-size:11px">terreno paradigma {AREA_PARADIGMA_M2:.0f} m2 &middot;
      referência {DATA_REFERENCIA} &middot; configuração {CONFIGURACAO}</span><br>
      {escala}<br>
      <span>{minimo:,.0f}</span>
      <span style="float:right">{maximo:,.0f} {unidade}</span>
    </div>
    {{% endmacro %}}""")
    mapa.get_root().add_child(legenda)

    caminho = DIR_MAPAS / arquivo
    mapa.save(str(caminho))
    print(f"  {caminho.name}")
    return mapa

# %%
# Escala comum ao piso, à estimativa central e ao teto, para que os três sejam
# comparáveis a olho. A amplitude e o PINAW têm escala própria.
piso_teto_min = consolidado["unit_q10"].min()
piso_teto_max = consolidado["unit_q90"].max()
print("mapas HTML:")
mapa_q10 = mapa_folium(
    consolidado, "unit_q10", "Piso do intervalo — quantil 0,10",
    f"mapa_q10_{sufixo}.html", piso_teto_min, piso_teto_max)
mapa_q50 = mapa_folium(
    consolidado, "unit_q50", "Estimativa central — quantil 0,50",
    f"mapa_q50_{sufixo}.html", piso_teto_min, piso_teto_max)
mapa_q90 = mapa_folium(
    consolidado, "unit_q90", "Teto do intervalo — quantil 0,90",
    f"mapa_q90_{sufixo}.html", piso_teto_min, piso_teto_max)
mapa_amp = mapa_folium(
    consolidado, "amplitude_unit", "Amplitude do intervalo — q0,90 menos q0,10",
    f"mapa_amplitude_{sufixo}.html")
mapa_pinaw = mapa_folium(
    consolidado, "pinaw_pontual",
    "Largura normalizada do intervalo — PINAW pontual",
    f"mapa_pinaw_{sufixo}.html", unidade="w_i* = w_i / R")
# Out:
# mapas HTML:
#   mapa_q10_cfg60_450m2.html
#   mapa_q50_cfg60_450m2.html
#   mapa_q90_cfg60_450m2.html
#   mapa_amplitude_cfg60_450m2.html
#   mapa_pinaw_cfg60_450m2.html

# %% [markdown]
# ## 7. Versões em PDF
#
# Mesmo conteúdo dos mapas HTML, em figura estática para o artigo.

# %%
def mapa_pdf(dados, coluna, titulo, arquivo, minimo=None, maximo=None, unidade="R$/m$^2$"):
    """Figura estática equivalente ao mapa HTML."""
    minimo = dados[coluna].min() if minimo is None else minimo
    maximo = dados[coluna].max() if maximo is None else maximo

    figura, eixo = plt.subplots(figsize=(11, 9))
    dispersao = eixo.scatter(
        dados.utm_x / 1000, dados.utm_y / 1000, c=dados[coluna],
        cmap=CMAP, vmin=minimo, vmax=maximo, s=1.2, marker="s", linewidths=0,
    )
    eixo.set_aspect("equal")
    eixo.set_xlabel("UTM E (km)")
    eixo.set_ylabel("UTM N (km)")
    eixo.set_title(
        f"{titulo}\nterreno paradigma {AREA_PARADIGMA_M2:.0f} m$^2$ · "
        f"referência {DATA_REFERENCIA} · configuração {CONFIGURACAO}",
        fontsize=11,
    )
    barra = figura.colorbar(dispersao, ax=eixo, shrink=0.8)
    barra.set_label(unidade)
    figura.tight_layout()

    caminho = DIR_MAPAS / arquivo
    figura.savefig(caminho, dpi=300, bbox_inches="tight")
    print(f"  {caminho.name}")
    return figura


print("figuras PDF:")
fig_q10 = mapa_pdf(consolidado, "unit_q10", "Piso do intervalo — quantil 0,10",
                   f"mapa_q10_{sufixo}.pdf", piso_teto_min, piso_teto_max)
fig_q50 = mapa_pdf(consolidado, "unit_q50", "Estimativa central — quantil 0,50",
                   f"mapa_q50_{sufixo}.pdf", piso_teto_min, piso_teto_max)
fig_q90 = mapa_pdf(consolidado, "unit_q90", "Teto do intervalo — quantil 0,90",
                   f"mapa_q90_{sufixo}.pdf", piso_teto_min, piso_teto_max)
fig_amp = mapa_pdf(consolidado, "amplitude_unit",
                   "Amplitude do intervalo — q0,90 menos q0,10",
                   f"mapa_amplitude_{sufixo}.pdf")
fig_pinaw = mapa_pdf(
    consolidado, "pinaw_pontual",
    "Largura normalizada do intervalo — PINAW pontual",
    f"mapa_pinaw_{sufixo}.pdf",
    unidade=r"$w_i^* = (\hat{Q}_{0.90} - \hat{Q}_{0.10})\,/\,R$")
plt.show()
# Out:
# figuras PDF:
#   mapa_q10_cfg60_450m2.pdf
#   mapa_q50_cfg60_450m2.pdf
#   mapa_q90_cfg60_450m2.pdf
#   mapa_amplitude_cfg60_450m2.pdf
#   mapa_pinaw_cfg60_450m2.pdf

# %%
# Registro do que foi produzido, ao lado dos arquivos.
registro = {
    "data_execucao": datetime.now().isoformat(timespec="seconds"),
    "data_referencia": DATA_REFERENCIA,
    "area_paradigma_m2": AREA_PARADIGMA_M2,
    "configuracao": CONFIGURACAO,
    "grupos": GRUPOS,
    "n_colunas": len(COLUNAS),
    "r2_teste_etapa2": float(linha.r2),
    "r2_teste_reproduzido": float(r2_conferido),
    "tps_smoothing": SMOOTHING,
    "tps_amostra_ajuste": "train (8.532), superfície completa; treino mantém o out-of-fold do canônico",
    "quantis": QUANTIS,
    "pinc": 0.80,
    "R_teste_log": R_TESTE,
    "pinaw_global": PINAW,
    "pinaw_por_cidade": {c: round(float(v), 6) for c, v in
                         consolidado.groupby("cidade").pinaw_pontual.mean().items()},
    "crs_grid": CRS_GRID,
    "cidades": sorted(grids),
    "n_pontos": int(len(consolidado)),
    "chave": "id_ponto = CIDADE_ID * 10^7 + posicao da linha no arquivo de origem",
}
caminho = DIR_RESULTADOS / f"registro_{sufixo}.json"
caminho.write_text(json.dumps(registro, indent=2, ensure_ascii=False))
print(json.dumps(registro, indent=2, ensure_ascii=False))
# Out:
# {
#   "data_execucao": "2026-08-07T06:44:44",
#   "data_referencia": "2026-08-01",
#   "area_paradigma_m2": 450.0,
#   "configuracao": 60,
#   "grupos": "BASE + CENSUS + RS + COORDS + EMBED",
#   "n_colunas": 80,
#   "r2_teste_etapa2": 0.7073370833062866,
#   "r2_teste_reproduzido": 0.7073370833062866,
#   "tps_smoothing": 1.0,
#   "tps_amostra_ajuste": "train (8.532), superfície completa; treino mantém o out-of-fold do canônico",
#   "quantis": [
#     0.1,
#     0.5,
#     0.9
#   ],
#   "pinc": 0.8,
#   "R_teste_log": 3.7773534262602864,
#   "pinaw_global": 0.277747995397427,
#   "pinaw_por_cidade": {
#     "Apucarana": 0.260774,
#     "Arapongas": 0.252889,
#     "Cambe": 0.286418,
#     "Cambira": 0.261876,
#     "Ibipora": 0.332466,
#     "Jandaia": 0.306984,
#     "Londrina": 0.326397,
#     "Mandaguari": 0.276234,
#     "Marialva": 0.247556,
#     "Maringa": 0.204553,
#     "Rolandia": 0.278724,
#     "Sarandi": 0.332561
#   },
#   "crs_grid": "EPSG:29192",
#   "cidades": [
# ...
